# %%
#Importerar bibliotek x2
import pandas as pd
import matplotlib.pyplot as plt

#skapar min första funktion(skapade funktionerna så att jag kunde tästa dem var för sig)
def function():
    #läser in csv filen med hjälp av pandas
    wf=pd.read_csv('Gender_Data.csv')
    #skapar etikett till båda sidorna av pie-charten
    my_labels=['Male', 'Female']
    #använder pandas.DataFrame för att struckyuera upp pie-charten
    df = pd.DataFrame(data=wf)
    #skapar själva grafen
    df.plot.pie(title="Gender difference",y='Total_Cases',
     #lägger in mina etiketter med labels=my_labels och ger sidorna procent tal med autopct='%1.1f%%' vilket ger       procent med en decimal
                    labels=my_labels, autopct='%1.1f%%')
                   
#andra funktionen
def function1():
    #läser in excel filen med pandas
    wf = pd.read_excel('Sweden_raw_data.xls', sheet_name=3, index_col=0,legend=True)
    #använder pandas.DataFrame för att struckyuera upp stapeldiagramet
    df = pd.DataFrame(data=wf)
    #skapar själva stapeldiagramet
    df.plot.bar(title='Region',y='Totalt_antal_fall',)
#sätter ut mina funktioner så att de kan ses
function()
function1()
